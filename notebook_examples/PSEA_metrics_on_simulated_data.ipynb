# %% [markdown]
# <a href="https://colab.research.google.com/github/Dowell-Lab/psea/blob/main/notebook_examples/PSEA_metrics_on_simulated_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
#need to change this to the psea_results for the simulated data which is at /Users/allenma/outpsea
url="https://raw.githubusercontent.com/Dowell-Lab/psea/refs/heads/main/testdata/psea_scores_20240923-152820.adjpval.csv"
resultsdf = pd.read_csv(url, index_col=0)
resultsdf
# Out:
#             binary_attribute            value   runpsea       NES  \
# 24553   patent_foramen_ovale  ENSG00000232010  included -5.964690
# 24239   patent_foramen_ovale  ENSG00000183255  included  5.575281
# 20802       obesity_disorder  ENSG00000155307  included -5.458382
# 24578   patent_foramen_ovale  ENSG00000233056  included -5.329486
# 24818   patent_foramen_ovale  ENSG00000277117  included -5.238081
# ...                      ...              ...       ...       ...
# 121321     Tourette_syndrome  ENSG00000283051  excluded       NaN
# 121322     Tourette_syndrome  ENSG00000283300  excluded       NaN
# 121323     Tourette_syndrome  ENSG00000283904  excluded       NaN
# 121324     Tourette_syndrome  ENSG00000284448  excluded       NaN
# 121325     Tourette_syndrome  ENSG00000284550  excluded       NaN
#
#                 pval  p_value_bonf  p_value_holm  p_value_BenjaminiHochberg  \
# 24553   6.628414e-12  1.113375e-07  1.113375e-07               1.113375e-07
# 24239   2.543059e-10  4.271576e-06  4.271322e-06               2.135788e-06
# 20802   6.326142e-10  1.062602e-05  1.062476e-05               3.542007e-06
# 24578   1.273144e-08  2.138500e-04  2.137991e-04               3.838521e-05
# 24818   1.371145e-08  2.303113e-04  2.302427e-04               3.838521e-05
# ...              ...           ...           ...                        ...
# 121321           NaN           NaN           NaN                        NaN
# 121322           NaN           NaN           NaN                        NaN
# 121323           NaN           NaN           NaN                        NaN
# 121324           NaN           NaN           NaN                        NaN
# 121325           NaN           NaN           NaN                        NaN
#
#         p_value_BenjaminiYekutieli
# 24553                     0.000001
# 24239                     0.000022
# 20802                     0.000037
# 24578                     0.000396
# 24818                     0.000396
# ...                            ...
# 121321                         NaN
# 121322                         NaN
# 121323                         NaN
# 121324                         NaN
# 121325                         NaN
#
# [121326 rows x 9 columns]

# %%
def parse_simulated_binary_att(row):

# %%
#this is not done yet but is a first draft
def parse_simulated_binary_att(row):
  simulated_binary_attribute = row["binary_attribute"]
  # Split the simulated_binary_attribute string by underscores
  parts = simulated_binary_attribute.split('_')
  print("parts", parts)
  # Extract the gene name
  genename = parts[0]
  print("genename", genename)
  # Extract the other values using a dictionary for easier parsing
  extracted_values = {}
  for part in parts[1:]:
      if 'Truesamplesize' in part:
          extracted_values['samples_true'] = int(part.replace('Truesamplesize', ''))
      elif 'biassamplesize' in part:
          extracted_values['samples_true_bias'] = int(part.replace('biassamplesize', ''))
      elif 'Zscorevaluebais' in part:
          extracted_values['Zscore_valuebais'] = float(part.replace('Zscorevaluebais', ''))
      elif 'sigma' in part:
          extracted_values['Zscore_valuebais_sigma'] = float(part.replace('sigma', ''))
      elif 'direction' in part:
          extracted_values['top_or_bottom'] = part.replace('direction_', '')
      elif 'pba' in part:
          extracted_values['percent_binary_attributes_thatarevaluebias'] = float(part.replace('pba', ''))

  return genename, extracted_values
